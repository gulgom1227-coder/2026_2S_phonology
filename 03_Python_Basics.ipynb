# %% [markdown]
# <a href="https://colab.research.google.com/github/hby1117/class2026Fall/blob/main/03_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics

# %% [markdown]
# ## 1. Flow >> 일을 효율적으로 만드는 과정, 어떤 흐름으로 일을 하게 하는지
#
# 1. if > 조건문
# 2. for
# 3. while

# %% [markdown]
# ### If
# ```python
# # Compare
# a == b
# a != b
# a > b
# a >= b
# a < b
# a <= b
# ```
# ```python
# # Logical Operation
# a and b
# a or b
# not a
# ```
# ```python
# # Syntax
# if condition:
#   # execute this code block
# elif another_condition:
#   # execute this code block
# else:
#   # execute this code block
# ```

# %%
# 예시: 가게 웨이팅 안내 메시지
waiting_teams = 5

# 대기팀 수에 따라 안내 메시지를 다르게 출력한다.

# %% [markdown]
# ### For
# ```python
# # Syntax
# for item in sequence:
# 	# execute this code block for each item
# ```

# %%
# 예시: 플레이리스트 재생하기

# 플레이리스트 안에 있는 곡을 차례로 하나씩 재생한다.

# %%
#  예시: 일주일 걸음 수 목표 확인하기
daily_steps = [7200, 10500, 8300, 12400, 10000, 6500, 11300]

goal = 10000
success_days = 0

# 일주일 동안 목표를 달성한 일수를 계산한다.

# %% [markdown]
# ### While
# ```python
# # Syntax
# while condition:
# 	# execute this code block as long as the condition is true
# ```

# %%
# 예시: 카페 쿠폰 스탬프 채우기
stamp = 0
target = 10

# 스탬프가 10개가 될 때까지 스탬프를 적립한다.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Function
# ```python
# # Define
# def function_name(parameters):
#   # Code block
#   return result
# ```
# ```python
# # Call
# output_data = function_name(input_data)

# %% [markdown]
# # 예시: 더치페이 계산기
#
# # 더치페이 계산기를 만들고 여러 상황에서 사용해본다.

# %% [markdown]
# ```python
# # Function scope
# global_var = "global"
#
# def custom_func():
# 	local_var = "local"
# 	print(global_var)
# 	print(local_var)
#
# custom_func()
# print(global_var)
# print(local_var)  # This raises an error
# ```
